# %%
import zarr

# Load the Zarr file
zarr_file = zarr.open("data/Xenium/lung_cancer_sample1/cells.zarr.zip", mode='r')

# Access and display the `cell_index` from polygon_sets/0
cell_index_0 = zarr_file['polygon_sets/0/cell_index'][:]
print("cell_index for polygon_set 0:", cell_index_0)

# Access and display the `cell_index` from polygon_sets/1
cell_index_1 = zarr_file['polygon_sets/1/cell_index'][:]
print("cell_index for polygon_set 1:", cell_index_1)
# Out:
# cell_index for polygon_set 0: [     0      1      2 ... 160997 160998 160999]
# cell_index for polygon_set 1: [     0      1      2 ... 160997 160998 160999]

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('data/embeddings/lung_cancer_sample2.h5ad')
adata.obs.index = range(1, len(adata.obs) + 1)
adata.obs
# Out:
#         n_genes
# 1            15
# 2            38
# 3            18
# 4            33
# 5            62
# ...         ...
# 161890       10
# 161891        3
# 161892        6
# 161893        2
# 161894        1
#
# [161894 rows x 1 columns]

# %%
adata.write('data/embeddings/xenium_lung_sample2_0.h5ad')

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("cuDNN version:", torch.backends.cudnn.version())
print("cuDNN enabled:", torch.backends.cudnn.enabled)
print("GPU device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# CUDA available: False
# cuDNN version: 90100
# cuDNN enabled: True
# GPU device: None
